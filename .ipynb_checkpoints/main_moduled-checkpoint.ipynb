# %%
import tools


features = '''match_id, match_outcome, winning_team, hero_id, team, 
        match_mode, average_badge_team0, "stats.time_stamp_s", "stats.net_worth", 
        "mid_boss.destroyed_time_s", "mid_boss.team_claimed"'''

dataset = tools.get_match_dataframe(features, 1000)
heroes = tools.get_heroes_dataframe()

display(heroes)
display(dataset)
# Out:
# ┌────────────────────────────────────┐
# │                name                │
# │              varchar               │
# ├────────────────────────────────────┤
# │ ability_items_dict                 │
# │ accounts_to_update                 │
# │ active_matches                     │
# │ demo_player                        │
# │ hero_leaderboard                   │
# │ hero_mmr_history                   │
# │ heroes                             │
# │ items                              │
# │ leaderboard                        │
# │ match_player                       │
# │ match_salts                        │
# │ mmr_history                        │
# │ player_card                        │
# │ player_match_by_match              │
# │ player_match_counts30d_dict        │
# │ player_match_history               │
# │ steam_profile_observed_names       │
# │ tmp_codec_src                      │
# │ tmp_codec_xpos                     │
# │ tmp_itemstats14_match_player_slice │
# │ upgrade_items_dict                 │
# └────────────────────────────────────┘
#                21 rows
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 features = '''match_id, match_outcome, winning_team, hero_id, team,
#       5         match_mode, average_badge_team0, "stats.time_stamp_s", "stats.net_worth",
#       6         "mid_boss.destroyed_time_s", "mid_boss.team_claimed"'''
#       7
# ----> 8 dataset = tools.get_match_dataframe(features, 1000)
#       9 heroes = tools.get_heroes_dataframe()
#      10
#      11 display(heroes)
#
# File ~\MLprojects\DeadlockProject\tools.py:8, in get_match_dataframe(features, limit)
#       4 def get_match_dataframe(features : str, limit : int):
#       5     DUCKLAKE_URL = "ducklake:https://s3-cache.deadlock-api.com/db-snapshot/public/db_snapshot.ducklake"
# ----> 8     with duckdb.connect() as con:
#       9         con.execute("""
#      10             INSTALL ducklake; LOAD ducklake;
#      11             INSTALL httpfs; LOAD httpfs;
#    (...)     15             );
#      16         """)
#      17         con.execute(f"ATTACH '{DUCKLAKE_URL}' AS db (READ_ONLY)")
#
# File ~\MLprojects\DeadlockProject\tools.py:23, in get_match_dataframe(features, limit)
#      20 # Tables are now queryable directly:
#      21 con.sql("SHOW TABLES").show()
# ---> 23 dataset = con.sql( 'SELECT ' + features + " FROM read_parquet(['s3://db-snapshot/public/match_player/match_player_84.parquet']) " +
#      24                 'WHERE average_badge_team0 > 90 AND average_badge_team1 > 90 AND match_outcome = \'TeamWin\' '
#      25                 'LIMIT ' + limit + ';').df()
#      26 return dataset
#      27 heroes = con.sql("SELECT * FROM heroes").df()
#
# TypeError: can only concatenate str (not "int") to str
